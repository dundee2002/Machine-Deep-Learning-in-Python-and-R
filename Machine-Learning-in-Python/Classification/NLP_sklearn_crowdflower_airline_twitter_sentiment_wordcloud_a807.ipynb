# %% [markdown]
# ## NLP & MultiClass Classification: Airline Twitter sentiment data
# https://www.crowdflower.com/data-for-everyone/
#
# ** Dataset Information: **
#
# - 14640 Scraped Twitter data for major U.S. airlines including positive, negative, and neutral tweets
#
# ** Attribute Information:**
#
# - _unit_id
# - _golden
# - _unit_state
# - _trusted_judgments
# - _last_judgment_at
# - airline_sentiment
# - airline_sentiment:confidence
# - negativereason
# - negativereason:confidence
# - airline
# - airline_sentiment_gold
# - name
# - negativereason_gold
# - retweet_count
# - text
# - tweet_coord
# - tweet_created
# - tweet_id
# - tweet_location
# - user_timezone
#
# ** Objective of this project **
#
# predict sentiment from tweets
#  - positive, negative, and neutral for multi-class
#  - negative or not (positive and neutral) for binary-class

# %% [markdown]
# # Data

# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load Data
df = pd.read_csv('Airline-Sentiment-2-w-AA.csv', encoding='latin')
pd.set_option('display.max_colwidth', -1)
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  681448150  False    finalized   3                   2/25/15 5:24
# 1  681448153  False    finalized   3                   2/25/15 1:53
# 2  681448156  False    finalized   3                   2/25/15 10:01
# 3  681448158  False    finalized   3                   2/25/15 3:05
# 4  681448159  False    finalized   3                   2/25/15 5:50
#
#   airline_sentiment  airline_sentiment:confidence negativereason  \
# 0  neutral           1.0000                        NaN
# 1  positive          0.3486                        NaN
# 2  neutral           0.6837                        NaN
# 3  negative          1.0000                        Bad Flight
# 4  negative          1.0000                        Can't Tell
#
#    negativereason:confidence         airline airline_sentiment_gold  \
# 0 NaN                         Virgin America  NaN
# 1  0.0000                     Virgin America  NaN
# 2 NaN                         Virgin America  NaN
# 3  0.7033                     Virgin America  NaN
# 4  1.0000                     Virgin America  NaN
#
#          name negativereason_gold  retweet_count  \
# 0  cairdin     NaN                 0
# 1  jnardino    NaN                 0
# 2  yvonnalynn  NaN                 0
# 3  jnardino    NaN                 0
# 4  jnardino    NaN                 0
#
#                                                                                                                              text  \
# 0  @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials to the experience... tacky.
# 2  @VirginAmerica I didn't today... Must mean I need to take another trip!
# 3  @VirginAmerica it's really aggressive to blast obnoxious "entertainment" in your guests' faces &amp; they have little recourse
# 4  @VirginAmerica and it's a really big bad thing about it
#
#   tweet_coord  tweet_created      tweet_id tweet_location  \
# 0  NaN         2/24/15 11:35  5.703060e+17  NaN
# 1  NaN         2/24/15 11:15  5.703010e+17  NaN
# 2  NaN         2/24/15 11:15  5.703010e+17  Lets Play
# 3  NaN         2/24/15 11:15  5.703010e+17  NaN
# 4  NaN         2/24/15 11:14  5.703010e+17  NaN
#
#                 user_timezone
# 0  Eastern Time (US & Canada)
# 1  Pacific Time (US & Canada)
# 2  Central Time (US & Canada)
# 3  Pacific Time (US & Canada)
# 4  Pacific Time (US & Canada)

# %%
df['text'].tail(100)
# Out:
# 14540    @AmericanAir tried ringing but told me to try again Late Flightr. I'm supposed to be leaving in an hour...
# 14541    @AmericanAir You guys did an amazing job today! Know itÛªs hard; thanks to Kate Appleton for all her hard work reFlight Booking Problems my friends and me!
# 14542    .@AmericanAir cover a rental car or refund our ticket? - I'll gladly drive 10 hrs home than be stuck here till Tues!
# 14543    @AmericanAir should reconsider #usairways acquisition. Flight 1843 AA gold flyers insulted by attendant for hanging jacket!
# 14544    @AmericanAir   You neglected to mention the $200 fee per ticket.  I had a medical reason and still have had to jump thru hoops.
# 14545    @AmericanAir yes and I would like a refund.
# 14546    @AmericanAir how realistic is it to make an 80 minute domestic to international transfer at JFK for a non US citizen?
# 14547    Eliza &amp; I cheated on u @AmericanAir with @AirTahitiNui &amp; it was a lovely flight. But we'll be back! Lots!
# 14548    @AmericanAir I hope you like the photo :) http://t.co/p7fSLuxEGW
# 14549    @AmericanAir @sweetmel If weather is bad, wouldn't your folks try extra hard to communicate...or load bags onto flight 1320...or...anything?
# 14550    @AmericanAir and how is this not a mechanical issue? All evidence points to the idea that itÛªs the ILS at CLL at fault, not the weather.
# 14551    @AmericanAir @CAexhibitions Sorry in, like, a general way? Or sorry that incompetence/understaffing is compounding weather issues?
# 14552    @AmericanAir please help us get home tomorrow!!!!!
# 14553    @AmericanAir @tennetexan Too bad there's only, like, 3 people on that team, then. Because this is next level unreal.
# 14554    @AmericanAir @marxsterbcow How is this a real life response to a customer service issue? Seriously. Keep trying to call us. Eh, might work.
# 14555    @AmericanAir fix the engine of flight AA3031so I don't spend all night in your airport so I can fly home tomorrow
# 14556    @AmericanAir Thank you.....you do the same!!
# 14557    @AmericanAir @ActingOutMgmnt Just make sure they remember to load the bags onto the plane. They Cancelled Flight the flight when they forget...
# 14558    @AmericanAir @brewcrewfan8 Is this real life, AA? Like, 2015 real life? You should be emailing/calling/DMing people you've inconvenienced.
# 14559    @AmericanAir hey there me again from yesterday im still on hold
# 14560    @AmericanAir weather is unavoidable. Understaffing is controllable
# 14561    @AmericanAir Not only was 5418 Late Flight, but we've been boarded and waiting for over 30min. WTF?
# 14562    @AmericanAir @yvonneokaka When do I get my personal response and apology for your crew's having forgotten to load baggage onto my flight?
# 14563    @AmericanAir All flts to JFK Cancelled Flightled Thx to UR agent at SFO Im rebooked on UA. Didn't get name. She was awesome!  #twitterhug #shesaidrun
# 14564    @AmericanAir I know.  After an hour I got a live person.  It messes up our arrival and car plans at two airports and is costing us more.
# 14565    @AmericanAir I can't get ahold of aadvantage reservations.  I need to ticket a reservation that Cancelled Flights soon.  can you help?
# 14566    @AmericanAir i was also told by agents my issues "aren't their prob" K fine. I get it. But have some compassion 4 others dealing w/this!!!
# 14567    @AmericanAir What's the status at DFW? Ticket agent at gate A9 was very rude and unhelpful.
# 14568    @AmericanAir i was spoken 2 like I'm an idiot and that is not OK!! I don't need to deal w/ that esp after the travel experience I've had
# 14569    @AmericanAir I am trying to switch my flight to AA 1359 I am currently on AA 2401 at 6:50am MONDAY morn then AA 2586! Help Me!!
#                                                                       ...
# 14610    @AmericanAir I understand the weather issue but you can't expect passengers to wait 24 hours inside airports for whatever reason. Outrageous
# 14611    @AmericanAir guarantee no retribution? If so, I'd be glad to share.
# 14612    @AmericanAir a friend is having flight Cancelled Flightlations out of LAX to CMH on Feb 23. Anyway to help her? 800 number has been no help
# 14613    @AmericanAir I used the "call back" feature with an operator regarding my flight, got a call 2 hours Late Flightr and got hung up on. #pleasehelp
# 14614    @AmericanAir I need to be at work tomorrow at 8am, therefore that doesn't help.  Direct message faster than calling 800 number? #Backwards
# 14615    @AmericanAir  ugh Dump us in dfw w/no luggage then Cancelled Flight our flight 3 more times. Sat arrival now Tue?
# 14616    @AmericanAir Cancelled Flights my flight, doesn't send an email, text or call. Then puts me on way earlier flight I might miss now. Thanks AA!
# 14617    @AmericanAir DMing you now! Big thanks.
# 14618    @AmericanAir 3078 is overweight so you pull 2 dozen passengers off? Why not luggage? Seriously?
# 14619    @AmericanAir I love your company and your staff is amazing. They just made an uncomfortable situation comfortable
# 14620    @AmericanAir I wait 2+ hrs for CS to call me back re why  flt is cxld/protection &amp; they hang up the minute I answer on 1st ring?
# 14621    @AmericanAir I've been on hold for 55 mins about my Cancelled Flighted international flight. Am out of country, so can't leave a call back #. Help?
# 14622    I just need a place to sleep when I land without accommodations in PLS @AmericanAir!
# 14623    @AmericanAir Love the new planes for the JFK-LAX run.  Maybe one day I will be on one where the amenities all function.  #NoCharge #Ever
# 14624    @AmericanAir Call me Chairman, or call me Emerald. After what you did today to me, you can call me a former customer.
# 14625    @AmericanAir Flight 236 was great. Fantastic cabin crew. A+ landing. #thankyou #JFK http://t.co/dRW08djHAI
# 14626    @AmericanAir Flight 953 NYC-Buenos Aires has been delay since yesterday at 10PM. Is going to take off at 3.30PM now? Give us answers!
# 14627    @AmericanAir Flight Cancelled Flightled, can't go home until tomorrow. I could use dinner and a play, @AmericanAir! It's my first time in NYC.
# 14628    Thank you. ÛÏ@AmericanAir: @jlhalldc Customer Relations will review your concerns and contact you back directly, John.Û
# 14629    @AmericanAir How do I change my flight if the phone system keeps telling me that the representatives are busy?
# 14630    @AmericanAir Thanks! He is.
# 14631    @AmericanAir thx for nothing on getting us out of the country and back to US. Broken plane? Come on. Get another one.
# 14632    ÛÏ@AmericanAir: @TilleyMonsta George, that doesn't look good. Please follow this link to start the refund process: http://t.co/4gr39s91DlÛ_Ù÷â
# 14633    @AmericanAir my flight was Cancelled Flightled, leaving tomorrow morning. Auto rebooked for a Tuesday night flight but need to arrive Monday.
# 14634    @AmericanAir right on cue with the delays_ÙÔÎ
# 14635    @AmericanAir thank you we got on a different flight to Chicago.
# 14636    @AmericanAir leaving over 20 minutes Late Flight. No warnings or communication until we were 15 minutes Late Flight. That's called shitty customer svc
# 14637    @AmericanAir Please bring American Airlines to #BlackBerry10
# 14638    @AmericanAir you have my money, you change my flight, and don't answer your phones! Any other suggestions so I can make my commitment??
# 14639    @AmericanAir we have 8 ppl so we need 2 know how many seats are on the next flight. Plz put us on standby for 4 people on the next flight?
# Name: text, Length: 100, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 20 columns):
# _unit_id                        14640 non-null int64
# _golden                         14640 non-null bool
# _unit_state                     14640 non-null object
# _trusted_judgments              14640 non-null int64
# _last_judgment_at               14584 non-null object
# airline_sentiment               14640 non-null object
# airline_sentiment:confidence    14640 non-null float64
# negativereason                  9178 non-null object
# negativereason:confidence       10522 non-null float64
# airline                         14640 non-null object
# airline_sentiment_gold          40 non-null object
# name                            14640 non-null object
# negativereason_gold             32 non-null object
# retweet_count                   14640 non-null int64
# text                            14640 non-null object
# tweet_coord                     1019 non-null object
# tweet_created                   14640 non-null object
# tweet_id                        14640 non-null float64
# tweet_location                  9907 non-null object
# user_timezone                   9820 non-null object
# dtypes: bool(1), float64(3), int64(3), object(13)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#            _unit_id  _trusted_judgments  airline_sentiment:confidence  \
# count  1.464000e+04  14640.000000        14640.000000
# mean   6.814957e+08  3.618648            0.900169
# std    8.504314e+04  11.858704           0.162830
# min    6.814482e+08  2.000000            0.335000
# 25%    6.814536e+08  3.000000            0.692300
# 50%    6.814578e+08  3.000000            1.000000
# 75%    6.814623e+08  3.000000            1.000000
# max    6.816798e+08  248.000000          1.000000
#
#        negativereason:confidence  retweet_count      tweet_id
# count  10522.000000               14640.000000   1.464000e+04
# mean   0.638298                   0.082650       5.692184e+17
# std    0.330440                   0.745778       7.791092e+14
# min    0.000000                   0.000000       5.675880e+17
# 25%    0.360600                   0.000000       5.685590e+17
# 50%    0.670600                   0.000000       5.694780e+17
# 75%    1.000000                   0.000000       5.698902e+17
# max    1.000000                   44.000000      5.703110e+17

# %% [markdown]
# ## Exploratory data analysis (EDA)

# %%
# inspect sentiment
sns.countplot(df['airline_sentiment'])
df['airline_sentiment'].value_counts() #imbalanced
# Out:
# negative    9178
# neutral     3099
# positive    2363
# Name: airline_sentiment, dtype: int64

# %%
# numetic features
num_cols = ['airline_sentiment:confidence','negativereason:confidence','retweet_count']
df[num_cols].hist(layout=(1,3),figsize=(9,3))
plt.tight_layout()

# %%
plt.figure(figsize=(9,3))
for i,name in enumerate(num_cols):
    plt.subplot(1,3,i+1)
    _ = df[num_cols[i]].plot(kind='box',title=name)
plt.tight_layout()

# %%
# categorical features
sns.countplot(df['airline']) 
df['airline'].value_counts()
# Out:
# United            3822
# US Airways        2913
# American          2759
# Southwest         2420
# Delta             2222
# Virgin America    504
# Name: airline, dtype: int64

# %%
#df['tweet_location'].value_counts()

# %%
# text length
df['text_length'] = df['text'].apply(len)
df[['airline_sentiment','text_length','text']].head()
# Out:
#   airline_sentiment  text_length  \
# 0  neutral           35
# 1  positive          72
# 2  neutral           71
# 3  negative          126
# 4  negative          55
#
#                                                                                                                              text
# 0  @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials to the experience... tacky.
# 2  @VirginAmerica I didn't today... Must mean I need to take another trip!
# 3  @VirginAmerica it's really aggressive to blast obnoxious "entertainment" in your guests' faces &amp; they have little recourse
# 4  @VirginAmerica and it's a really big bad thing about it

# %%
df['text_length'].describe()
# Out:
# count    14640.000000
# mean     104.118511
# std      36.256550
# min      12.000000
# 25%      77.000000
# 50%      115.000000
# 75%      136.000000
# max      229.000000
# Name: text_length, dtype: float64

# %%
df['text_length'].hist(bins=50)

# %%
g = sns.FacetGrid(df,col='airline_sentiment')
g.map(plt.hist,'text_length')

# %%
sns.boxplot(x='airline_sentiment',y='text_length',data=df,palette='rainbow')

# %%
sentiment = df.groupby('airline_sentiment').mean()
sentiment
# Out:
#                        _unit_id   _golden  _trusted_judgments  \
# airline_sentiment
# negative           6.815016e+08  0.003487  3.789823
# neutral            6.814867e+08  0.000968  3.221362
# positive           6.814846e+08  0.002116  3.474820
#
#                    airline_sentiment:confidence  negativereason:confidence  \
# airline_sentiment
# negative           0.933365                      0.731769
# neutral            0.823303                      0.000000
# positive           0.872039                      0.000000
#
#                    retweet_count      tweet_id  text_length
# airline_sentiment
# negative           0.093375       5.692602e+17  114.093702
# neutral            0.060987       5.691841e+17  87.785737
# positive           0.069403       5.691006e+17  86.794329

# %%
num_cols = num_cols + ['airline_sentiment','text_length']
sns.heatmap(df[num_cols].corr(), annot = True, cmap='coolwarm')

# %%
# negative reason
df['negativereason'].value_counts().plot(kind='bar', title='Negative Reasons')
plt.ylabel('Count')
plt.xticks(rotation=75)
plt.show()

# %%
# word cloud
from nltk.corpus import stopwords
from wordcloud import WordCloud
import re

def plot_word_cloud(sentiment):
    text = df[df['airline_sentiment']==sentiment]['text'].to_string()
    text = re.sub(r'http\S+', '', text)
    text = re.sub('(RT|via)((?:\\b\\W*@\\w+)+)', ' ', text)
    text = re.sub(r'@\S+', '', text)
    #text = re.sub(r'#\S+', '', text)
    text = re.sub('&amp', ' ', text)    
    text = re.sub('[^a-zA-Z]', ' ', text)

    wordcloud = WordCloud(
        relative_scaling=0.5,
        stopwords=set(stopwords.words('english'))).generate(text)

    plt.figure(figsize=(12,12))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# positive
plot_word_cloud('positive')

# %%
# negative
plot_word_cloud('negative')

# %%
# create new class 'negative' column --> binary class
dict_class = {'neutral':0, 'positive':0, 'negative':1}
df['negative'] = df['airline_sentiment'].map(dict_class)
df[['airline_sentiment','negative']].head()
# Out:
#   airline_sentiment  negative
# 0  neutral           0
# 1  positive          0
# 2  neutral           0
# 3  negative          1
# 4  negative          1

# %%
df['negative'].value_counts()
# Out:
# 1    9178
# 0    5462
# Name: negative, dtype: int64

# %% [markdown]
# # Text preprocessing

# %% [markdown]
# ** Clean text **

# %%
from nltk.stem.porter import PorterStemmer

corpus = []
for i in range(0, len(df)):
    text = re.sub('\[link]', '', df['text'][i]) 
    text = re.sub(r'http\S+', '', text)
    text = re.sub('(RT|via)((?:\\b\\W*@\\w+)+)', ' ', text)
    text = re.sub(r'@\S+', '', text)
    #text = re.sub(r'#\S+', '', text)
    text = re.sub('&amp', ' ', text)    
    text = re.sub('[^a-zA-Z]', ' ', text)     
    text = text.lower().split() 
    text = [PorterStemmer() .stem(word) for word in text 
            if not word in set(stopwords.words('english'))]
    text = ' '.join(text) 
    corpus.append(text)

# %%
#i=10
#print(df['text'][i])
#print(corpus[i])

# %% [markdown]
# ** Creat Bag-Of-Words model **

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
X = CountVectorizer().fit_transform(corpus)
X = TfidfTransformer().fit_transform(X)
print(X.shape)
# Out:
# (14640, 8346)

# %% [markdown]
# ## 1. Binary Classification

# %%
y = df['negative'].values
seed = 101 #random seed for reproducibility
np.random.seed(seed)

# %% [markdown]
# #### Split Train Test sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                    stratify=y,random_state=seed)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (11712, 8346) (2928, 8346) (11712,) (2928,)

# %%
np.unique(y_train,return_counts=True) #similar ratio to original class
# Out:
# (array([0, 1], dtype=int64), array([4370, 7342], dtype=int64))

# %% [markdown]
# #### Model Train

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
# train model
model = RandomForestClassifier(n_estimators=100)
model.fit(X_train,y_train)

#accuracy score
y_pred_train = model.predict(X_train)
print('Accuracy: {:0.1f}%'.format(accuracy_score(y_train,y_pred_train)*100))

#classification report
print('\n')
print(classification_report(y_train, y_pred_train))

#confusion matrix
confmat = confusion_matrix(y_train, y_pred_train)

fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
for i in range(confmat.shape[0]):
    for j in range(confmat.shape[1]):
        ax.text(x=j, y=i, s=confmat[i, j], va='center', ha='center')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.tight_layout()
# Out:
# Accuracy: 99.7%
#
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      4370
#           1       1.00      1.00      1.00      7342
#
# avg / total       1.00      1.00      1.00     11712

# %% [markdown]
# #### Model Evaluation with Test set

# %%
# predict class with test set (new, unseen)
y_pred_test = model.predict(X_test)
print('Accuracy: {:0.1f}%'.format(accuracy_score(y_test,y_pred_test)*100))

#classification report
print('\n')
print(classification_report(y_test, y_pred_test))

#confusion matrix
confmat = confusion_matrix(y_test, y_pred_test)

fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
for i in range(confmat.shape[0]):
    for j in range(confmat.shape[1]):
        ax.text(x=j, y=i, s=confmat[i, j], va='center', ha='center')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.tight_layout()
# Out:
# Accuracy: 80.7%
#
#
#              precision    recall  f1-score   support
#
#           0       0.79      0.66      0.72      1092
#           1       0.82      0.89      0.85      1836
#
# avg / total       0.81      0.81      0.80      2928

# %% [markdown]
# ## 2. Multi-class Classification

# %%
y = df['airline_sentiment'].values
seed = 101 #random seed for reproducibility
np.random.seed(seed)

# %% [markdown]
# #### Split Train Test sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                    stratify=y,random_state=seed)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
np.unique(y_train,return_counts=True) #similar ratio to original class
# Out:
# (11712, 8346) (2928, 8346) (11712,) (2928,)
# (array(['negative', 'neutral', 'positive'], dtype=object),
#  array([7342, 2479, 1891], dtype=int64))

# %% [markdown]
# #### Model Train

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
# train model
model = RandomForestClassifier(n_estimators=100)
model.fit(X_train,y_train)

#accuracy score
y_pred_train = model.predict(X_train)
print('Accuracy: {:0.1f}%'.format(accuracy_score(y_train,y_pred_train)*100))

#classification report
print('\n')
print(classification_report(y_train, y_pred_train))

#confusion matrix
confmat = confusion_matrix(y_train, y_pred_train)

fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
for i in range(confmat.shape[0]):
    for j in range(confmat.shape[1]):
        ax.text(x=j, y=i, s=confmat[i, j], va='center', ha='center')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.tight_layout()
# Out:
# Accuracy: 99.3%
#
#
#              precision    recall  f1-score   support
#
#    negative       1.00      1.00      1.00      7342
#     neutral       0.98      0.98      0.98      2479
#    positive       0.98      0.99      0.99      1891
#
# avg / total       0.99      0.99      0.99     11712

# %% [markdown]
# #### Model Evaluation with Test set

# %%
# predict class with test set (new, unseen)
y_pred_test = model.predict(X_test)
print('Accuracy: {:0.1f}%'.format(accuracy_score(y_test,y_pred_test)*100))

#classification report
print('\n')
print(classification_report(y_test, y_pred_test))

#confusion matrix
confmat = confusion_matrix(y_test, y_pred_test)

fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
for i in range(confmat.shape[0]):
    for j in range(confmat.shape[1]):
        ax.text(x=j, y=i, s=confmat[i, j], va='center', ha='center')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.tight_layout()
# Out:
# Accuracy: 76.5%
#
#
#              precision    recall  f1-score   support
#
#    negative       0.79      0.93      0.85      1836
#     neutral       0.67      0.42      0.51       620
#    positive       0.75      0.58      0.65       472
#
# avg / total       0.75      0.77      0.75      2928
