# %% [markdown]
# ## NLP & Binary Classification: Twitter Global Warming sentiment data
# https://www.crowdflower.com/data-for-everyone/
#
# ** Dataset Information: **
#
# - 6090 tweets for belief in the existence of global warming or climate change. “Yes” if the tweet suggests global warming is occurring, “No” if not occurring.
#
# ** Attribute Information:**
#
# - tweet
# - existence
# - existence.confidence
#
# ** Objective of this project **
#
# - predict global warming sentiment (Yes or no) from tweets

# %% [markdown]
# # Data

# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load Data
df = pd.read_csv('1377884570_tweet_global_warming.csv', encoding='latin')
pd.set_option('display.max_colwidth', -1)
df.head()
# Out:
#                                                                                                                     tweet  \
# 0  Global warming report urges governments to act|BRUSSELS, Belgium (AP) - The world faces increased hunger and .. [link]
# 1  Fighting poverty and global warming in Africa [link]
# 2  Carbon offsets: How a Vatican forest failed to reduce global warming [link]
# 3  Carbon offsets: How a Vatican forest failed to reduce global warming [link]
# 4  URUGUAY: Tools Needed for Those Most Vulnerable to Climate Change [link]
#
#   existence  existence.confidence
# 0  Yes       1.0000
# 1  Yes       1.0000
# 2  Yes       0.8786
# 3  Yes       1.0000
# 4  Yes       0.8087

# %%
df.tail()
# Out:
#                                                                                                                                             tweet  \
# 6085  @bloodless_coup "The phrase 'global warming' should be abandoned in favor of 'climate change', Luntz says," http://bit.ly/7bIY0c #p2 #tcot
# 6086  Virginia to Investigate Global Warming Scientist Mann:  http://bit.ly/aDlavg
# 6087  Global warming you tube parody you will enjoy #IPCC #ocra http://bit.ly/bBGWhC
# 6088  One-Eyed Golfer: Don't dare tell me about global warming: Twenty-five of the forty-nine golfers making the cut thi... http://bit.ly/akeAxp
# 6089  man made global warming a hair brained theory 4 the scientifically challenged the IPPC has nothing to back up claims #tcot #p2 #climategate
#
#      existence  existence.confidence
# 6085  Y         1.0000
# 6086  NaN       1.0000
# 6087  N         0.6411
# 6088  N         1.0000
# 6089  N         1.0000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6090 entries, 0 to 6089
# Data columns (total 3 columns):
# tweet                   6090 non-null object
# existence               4225 non-null object
# existence.confidence    6087 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 142.8+ KB

# %%
df.describe()
# Out:
#        existence.confidence
# count  6087.000000
# mean   0.794478
# std    0.180054
# min    0.334600
# 25%    0.658500
# 50%    0.707600
# 75%    1.000000
# max    1.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
# missing data
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df[df['existence'].isnull()].head()
# Out:
#                                                                                                                                           tweet  \
# 14  Spring storm season starting a little late this year???  Must be global warming!
# 34  I truly  Fat ASS Gore should get the Scam Artist Award of the decade with his Global Warming and Energy Credits worth close to Billion.
# 40  Air ban led by flawed computer models. Global warming come to mind? [link]
# 47  Despite Climategate, LEFT investing heavily in global warming hysteria as new way 2 impose nat'l & international controls on human freedom.
# 48  Global warming you tube explanation you will enjoy #IPCC #teaparty [link]
#
#    existence  existence.confidence
# 14  NaN       1.0000
# 34  NaN      NaN
# 40  NaN      NaN
# 47  NaN      NaN
# 48  NaN       0.8485

# %%
df.dropna(inplace=True)
df.reset_index(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4225 entries, 0 to 4224
# Data columns (total 4 columns):
# index                   4225 non-null int64
# tweet                   4225 non-null object
# existence               4225 non-null object
# existence.confidence    4225 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 132.1+ KB

# %%
# inspect sentiment
sns.countplot(df['existence'])
df['existence'].value_counts() #imbalanced
# Out:
# Y      2554
# N      1053
# Yes    557
# No     61
# Name: existence, dtype: int64

# %%
# create new 'class' column
dict_class = {'Y':1, 'Yes':1, 'No':0, 'N':0}
df['class'] = df['existence'].map(dict_class)
df[['existence','class']].tail()
# Out:
#      existence  class
# 4220  Y         1
# 4221  Y         1
# 4222  N         0
# 4223  N         0
# 4224  N         0

# %%
sns.countplot(df['class'])
df['class'].value_counts()
# Out:
# 1    3111
# 0    1114
# Name: class, dtype: int64

# %%
# tweet length
df['tweet_length'] = df['tweet'].apply(len)
df[['class','tweet_length','tweet']].head()
# Out:
#    class  tweet_length  \
# 0  1      118
# 1  1      52
# 2  1      75
# 3  1      75
# 4  1      72
#
#                                                                                                                     tweet
# 0  Global warming report urges governments to act|BRUSSELS, Belgium (AP) - The world faces increased hunger and .. [link]
# 1  Fighting poverty and global warming in Africa [link]
# 2  Carbon offsets: How a Vatican forest failed to reduce global warming [link]
# 3  Carbon offsets: How a Vatican forest failed to reduce global warming [link]
# 4  URUGUAY: Tools Needed for Those Most Vulnerable to Climate Change [link]

# %%
df['tweet_length'].describe()
# Out:
# count    4225.000000
# mean     111.799763
# std      27.101025
# min      21.000000
# 25%      91.000000
# 50%      120.000000
# 75%      137.000000
# max      161.000000
# Name: tweet_length, dtype: float64

# %%
df['tweet_length'].hist(bins=50)

# %%
g = sns.FacetGrid(df,col='class')
g.map(plt.hist,'tweet_length')

# %%
sns.boxplot(x='class',y='tweet_length',data=df,palette='rainbow')

# %%
from nltk.corpus import stopwords
from wordcloud import WordCloud
import re

text = df['tweet'].to_string()
text = re.sub('\[link]', '', text) 
text = re.sub(r'http\S+', '', text) 
text = re.sub('(RT|via)((?:\\b\\W*@\\w+)+)', ' ', text)
text = re.sub(r'@\S+', '', text)
text = re.sub(r'#\S+', '', text)
text = re.sub('&amp', ' ', text)
text = re.sub('[^a-zA-Z]', ' ', text)

wordcloud = WordCloud(
    relative_scaling=0.5,
    stopwords=set(stopwords.words('english'))).generate(text)

plt.figure(figsize=(12,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# #### Clean Text

# %%
from nltk.corpus import stopwords
import re
def clean_text(s):
    s = re.sub('\[link]', '', s) 
    s = re.sub(r'http\S+', '', s) 
    s = re.sub('(RT|via)((?:\\b\\W*@\\w+)+)', ' ', s)
    s = re.sub(r'@\S+', '', s)
    s = re.sub(r'#\S+', '', s)
    s = re.sub('&amp', ' ', s)
    return ' '.join(filter(lambda word: word not in set(stopwords.words('english')), s.split()))

df['clean_text'] = df['tweet'].apply(clean_text)

# %%
X = df['clean_text']
y = df['class'].values

# %% [markdown]
# #### Spilt Train Test sets

# %%
# fix random seed for reproducibility
seed = 101
np.random.seed(seed)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.2,
                                                    stratify=y,
                                                    random_state=seed)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (3380,) (845,) (3380,) (845,)

# %% [markdown]
# #### Tokenize text

# %%
from keras.preprocessing.text import Tokenizer
max_features = 10000
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(X_train))
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
# Out:
# Using TensorFlow backend.

# %%
len(X_train)
#X_train[:10]
#tokenizer.word_counts
#tokenizer.word_index
# Out:
# 3380

# %%
totalNumWords = [len(one_comment) for one_comment in X_train]
plt.hist(totalNumWords,bins = 50)
plt.show()

# %%
from keras.preprocessing import sequence
max_words = max(totalNumWords)
X_train = sequence.pad_sequences(X_train, maxlen=max_words)
X_test = sequence.pad_sequences(X_test, maxlen=max_words)
print(X_train.shape,X_test.shape)
#X_train[np.argmax(totalNumWords)]
# Out:
# (3380, 25) (845, 25)

# %% [markdown]
# # 1. MLP

# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten,Embedding,Dropout
from keras.callbacks import EarlyStopping,ModelCheckpoint
from sklearn.metrics import roc_auc_score,accuracy_score,confusion_matrix,classification_report
import keras.backend as K

batch_size = 32
epochs = 100

def create_nn():
    np.random.seed(seed)
    K.clear_session()
    model = Sequential()
    model.add(Embedding(max_features, 128, input_length=X_train.shape[1]))
    model.add(Flatten())
    model.add(Dense(200, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    return model

# %%
# create the model
model = create_nn()
# callbacks
file_path = 'weights_best_nn.hdf5'
early_stop = EarlyStopping(monitor='val_acc', patience=10, verbose=0, mode='max') #'val_acc'
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max') #'val_acc'
callbacks_list = [checkpoint, early_stop]
# train the model
model_history = model.fit(X_train, y_train, validation_data=(X_test, y_test), 
                          epochs=epochs, batch_size=batch_size,
                          callbacks=callbacks_list, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 128)           1280000
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               640200
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                2020
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 1,942,341
# Trainable params: 1,942,341
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3380 samples, validate on 845 samples
# Epoch 1/100
# Epoch 00001: val_acc improved from -inf to 0.81775, saving model to weights_best_nn.hdf5
#  - 7s - loss: 0.5173 - acc: 0.7515 - val_loss: 0.4082 - val_acc: 0.8178
# Epoch 2/100
# Epoch 00002: val_acc improved from 0.81775 to 0.82367, saving model to weights_best_nn.hdf5
#  - 6s - loss: 0.2027 - acc: 0.9269 - val_loss: 0.4381 - val_acc: 0.8237
# Epoch 3/100
# Epoch 00003: val_acc improved from 0.82367 to 0.82959, saving model to weights_best_nn.hdf5
#  - 6s - loss: 0.0911 - acc: 0.9713 - val_loss: 0.4197 - val_acc: 0.8296
# Epoch 4/100
# Epoch 00004: val_acc improved from 0.82959 to 0.84142, saving model to weights_best_nn.hdf5
#  - 6s - loss: 0.0576 - acc: 0.9778 - val_loss: 0.4443 - val_acc: 0.8414
# Epoch 5/100
# Epoch 00005: val_acc improved from 0.84142 to 0.84615, saving model to weights_best_nn.hdf5
#  - 7s - loss: 0.0356 - acc: 0.9805 - val_loss: 0.5460 - val_acc: 0.8462
# Epoch 6/100
# Epoch 00006: val_acc did not improve
#  - 6s - loss: 0.0297 - acc: 0.9846 - val_loss: 0.6555 - val_acc: 0.8284
# Epoch 7/100
# Epoch 00007: val_acc did not improve
#  - 6s - loss: 0.0289 - acc: 0.9846 - val_loss: 0.7418 - val_acc: 0.8367
# Epoch 8/100
# Epoch 00008: val_acc did not improve
#  - 6s - loss: 0.0261 - acc: 0.9843 - val_loss: 0.7468 - val_acc: 0.8320
# Epoch 9/100
# Epoch 00009: val_acc did not improve
#  - 6s - loss: 0.0251 - acc: 0.9852 - val_loss: 0.7621 - val_acc: 0.8367
# Epoch 10/100
# Epoch 00010: val_acc did not improve
#  - 6s - loss: 0.0251 - acc: 0.9849 - val_loss: 0.7972 - val_acc: 0.8379
# Epoch 11/100
# Epoch 00011: val_acc did not improve
#  - 6s - loss: 0.0251 - acc: 0.9855 - val_loss: 0.7397 - val_acc: 0.8343
# Epoch 12/100
# Epoch 00012: val_acc did not improve
#  - 6s - loss: 0.0245 - acc: 0.9855 - val_loss: 0.7634 - val_acc: 0.8379
# Epoch 13/100
# Epoch 00013: val_acc did not improve
#  - 6s - loss: 0.0239 - acc: 0.9855 - val_loss: 0.7949 - val_acc: 0.8343
# Epoch 14/100
# Epoch 00014: val_acc did not improve
#  - 6s - loss: 0.0242 - acc: 0.9855 - val_loss: 0.8024 - val_acc: 0.8379
# Epoch 15/100
# Epoch 00015: val_acc did not improve
#  - 6s - loss: 0.0267 - acc: 0.9852 - val_loss: 0.6809 - val_acc: 0.8260

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
plot_model_history(model_history)

# %%
def model_evaluate(file_path):
    # predict class with test set
    model.load_weights(file_path)
    y_pred_test =  model.predict_classes(X_test, batch_size=batch_size, verbose=0)
    print('Accuracy:\t{:0.1f}%'.format(accuracy_score(y_test,y_pred_test)*100))
    print('roc auc:\t{:0.3f}'.format(roc_auc_score(y_test,y_pred_test)))

    #classification report
    print('\n')
    print(classification_report(y_test, y_pred_test))

    #confusion matrix
    confmat = confusion_matrix(y_test, y_pred_test)

    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(confmat.shape[0]):
        for j in range(confmat.shape[1]):
            ax.text(x=j, y=i, s=confmat[i, j], va='center', ha='center')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.tight_layout()

# %%
model_evaluate('weights_best_nn.hdf5')
# Out:
# Accuracy:	84.6%
# roc auc:	0.763
#
#
#              precision    recall  f1-score   support
#
#           0       0.78      0.59      0.67       223
#           1       0.86      0.94      0.90       622
#
# avg / total       0.84      0.85      0.84       845

# %% [markdown]
# # 2. 1D CNN

# %%
from keras.layers import Conv1D,MaxPooling1D
def create_cnn():
    np.random.seed(seed)
    K.clear_session()
    model = Sequential()
    model.add(Embedding(max_features, 128, input_length=X_train.shape[1]))
    model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(20, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    return model

# %%
# create the model
model = create_cnn()
# callbacks
file_path = 'weights_best_cnn.hdf5'
early_stop = EarlyStopping(monitor='val_acc', patience=10, verbose=0, mode='max') #'val_acc'
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max') #'val_acc'
callbacks_list = [checkpoint, early_stop]
# train the model
model_history = model.fit(X_train, y_train, validation_data=(X_test, y_test), 
                          epochs=epochs, batch_size=batch_size,
                          callbacks=callbacks_list, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 128)           1280000
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 25, 32)            12320
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 12, 32)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                7700
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 1,300,041
# Trainable params: 1,300,041
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3380 samples, validate on 845 samples
# Epoch 1/100
# Epoch 00001: val_acc improved from -inf to 0.74320, saving model to weights_best_cnn.hdf5
#  - 5s - loss: 0.5385 - acc: 0.7364 - val_loss: 0.4542 - val_acc: 0.7432
# Epoch 2/100
# Epoch 00002: val_acc improved from 0.74320 to 0.83077, saving model to weights_best_cnn.hdf5
#  - 4s - loss: 0.3356 - acc: 0.8589 - val_loss: 0.3945 - val_acc: 0.8308
# Epoch 3/100
# Epoch 00003: val_acc improved from 0.83077 to 0.84142, saving model to weights_best_cnn.hdf5
#  - 4s - loss: 0.1553 - acc: 0.9473 - val_loss: 0.4185 - val_acc: 0.8414
# Epoch 4/100
# Epoch 00004: val_acc did not improve
#  - 4s - loss: 0.0981 - acc: 0.9692 - val_loss: 0.4678 - val_acc: 0.8308
# Epoch 5/100
# Epoch 00005: val_acc did not improve
#  - 4s - loss: 0.0712 - acc: 0.9775 - val_loss: 0.5175 - val_acc: 0.8260
# Epoch 6/100
# Epoch 00006: val_acc did not improve
#  - 4s - loss: 0.0636 - acc: 0.9769 - val_loss: 0.5107 - val_acc: 0.8249
# Epoch 7/100
# Epoch 00007: val_acc did not improve
#  - 4s - loss: 0.0563 - acc: 0.9778 - val_loss: 0.5319 - val_acc: 0.8331
# Epoch 8/100
# Epoch 00008: val_acc improved from 0.84142 to 0.84260, saving model to weights_best_cnn.hdf5
#  - 4s - loss: 0.0491 - acc: 0.9790 - val_loss: 0.5983 - val_acc: 0.8426
# Epoch 9/100
# Epoch 00009: val_acc did not improve
#  - 4s - loss: 0.0487 - acc: 0.9799 - val_loss: 0.5420 - val_acc: 0.8260
# Epoch 10/100
# Epoch 00010: val_acc improved from 0.84260 to 0.85089, saving model to weights_best_cnn.hdf5
#  - 4s - loss: 0.0452 - acc: 0.9805 - val_loss: 0.5653 - val_acc: 0.8509
# Epoch 11/100
# Epoch 00011: val_acc did not improve
#  - 4s - loss: 0.0402 - acc: 0.9820 - val_loss: 0.6412 - val_acc: 0.8450
# Epoch 12/100
# Epoch 00012: val_acc did not improve
#  - 4s - loss: 0.0433 - acc: 0.9802 - val_loss: 0.5722 - val_acc: 0.8272
# Epoch 13/100
# Epoch 00013: val_acc did not improve
#  - 4s - loss: 0.0420 - acc: 0.9814 - val_loss: 0.5564 - val_acc: 0.8284
# Epoch 14/100
# Epoch 00014: val_acc did not improve
#  - 4s - loss: 0.0413 - acc: 0.9793 - val_loss: 0.5552 - val_acc: 0.8249
# Epoch 15/100
# Epoch 00015: val_acc did not improve
#  - 4s - loss: 0.0406 - acc: 0.9811 - val_loss: 0.5758 - val_acc: 0.8189
# Epoch 16/100
# Epoch 00016: val_acc did not improve
#  - 4s - loss: 0.0379 - acc: 0.9802 - val_loss: 0.5967 - val_acc: 0.8402
# Epoch 17/100
# Epoch 00017: val_acc did not improve
#  - 4s - loss: 0.0373 - acc: 0.9799 - val_loss: 0.5866 - val_acc: 0.8343
# Epoch 18/100
# Epoch 00018: val_acc did not improve
#  - 4s - loss: 0.0360 - acc: 0.9802 - val_loss: 0.5714 - val_acc: 0.8296
# Epoch 19/100
# Epoch 00019: val_acc did not improve
#  - 4s - loss: 0.0350 - acc: 0.9808 - val_loss: 0.6047 - val_acc: 0.8355
# Epoch 20/100
# Epoch 00020: val_acc did not improve
#  - 4s - loss: 0.0368 - acc: 0.9808 - val_loss: 0.6071 - val_acc: 0.7858

# %%
plot_model_history(model_history)

# %%
model_evaluate('weights_best_cnn.hdf5')
# Out:
# Accuracy:	85.1%
# roc auc:	0.779
#
#
#              precision    recall  f1-score   support
#
#           0       0.77      0.63      0.69       223
#           1       0.87      0.93      0.90       622
#
# avg / total       0.85      0.85      0.85       845

# %% [markdown]
# # 3. RNN

# %%
from keras.layers import LSTM
def create_rnn():
    np.random.seed(seed)
    K.clear_session()
    model = Sequential()
    model.add(Embedding(max_features, 128, input_length=X_train.shape[1]))
    model.add(LSTM(100, dropout=0.1, recurrent_dropout=0.1))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    return model

# %%
# create the model
model = create_rnn()
# callbacks
file_path = 'weights_best_rnn.hdf5'
early_stop = EarlyStopping(monitor='val_acc', patience=10, verbose=0, mode='max') #'val_acc'
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max') #'val_acc'
callbacks_list = [checkpoint, early_stop]
# train the model
model_history = model.fit(X_train, y_train, validation_data=(X_test, y_test), 
                          epochs=epochs, batch_size=batch_size,
                          callbacks=callbacks_list, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 128)           1280000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               91600
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                2020
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 1,373,641
# Trainable params: 1,373,641
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3380 samples, validate on 845 samples
# Epoch 1/100
# Epoch 00001: val_acc improved from -inf to 0.80947, saving model to weights_best_rnn.hdf5
#  - 10s - loss: 0.5291 - acc: 0.7536 - val_loss: 0.4150 - val_acc: 0.8095
# Epoch 2/100
# Epoch 00002: val_acc improved from 0.80947 to 0.84734, saving model to weights_best_rnn.hdf5
#  - 8s - loss: 0.2824 - acc: 0.8911 - val_loss: 0.3757 - val_acc: 0.8473
# Epoch 3/100
# Epoch 00003: val_acc did not improve
#  - 7s - loss: 0.1500 - acc: 0.9470 - val_loss: 0.4084 - val_acc: 0.8343
# Epoch 4/100
# Epoch 00004: val_acc did not improve
#  - 8s - loss: 0.0948 - acc: 0.9666 - val_loss: 0.4678 - val_acc: 0.8450
# Epoch 5/100
# Epoch 00005: val_acc did not improve
#  - 8s - loss: 0.0763 - acc: 0.9719 - val_loss: 0.5993 - val_acc: 0.8414
# Epoch 6/100
# Epoch 00006: val_acc did not improve
#  - 10s - loss: 0.0582 - acc: 0.9763 - val_loss: 0.5788 - val_acc: 0.8450
# Epoch 7/100
# Epoch 00007: val_acc did not improve
#  - 9s - loss: 0.0487 - acc: 0.9763 - val_loss: 0.7391 - val_acc: 0.8343
# Epoch 8/100
# Epoch 00008: val_acc did not improve
#  - 8s - loss: 0.0405 - acc: 0.9769 - val_loss: 0.8072 - val_acc: 0.8438
# Epoch 9/100
# Epoch 00009: val_acc did not improve
#  - 9s - loss: 0.0455 - acc: 0.9796 - val_loss: 0.6314 - val_acc: 0.8414
# Epoch 10/100
# Epoch 00010: val_acc did not improve
#  - 9s - loss: 0.0389 - acc: 0.9805 - val_loss: 0.7791 - val_acc: 0.8331
# Epoch 11/100
# Epoch 00011: val_acc did not improve
#  - 9s - loss: 0.0340 - acc: 0.9820 - val_loss: 0.8016 - val_acc: 0.8391
# Epoch 12/100
# Epoch 00012: val_acc did not improve
#  - 8s - loss: 0.0315 - acc: 0.9843 - val_loss: 0.8958 - val_acc: 0.8343

# %%
plot_model_history(model_history)

# %%
model_evaluate('weights_best_rnn.hdf5')
# Out:
# Accuracy:	84.7%
# roc auc:	0.778
#
#
#              precision    recall  f1-score   support
#
#           0       0.75      0.63      0.69       223
#           1       0.88      0.92      0.90       622
#
# avg / total       0.84      0.85      0.84       845

# %% [markdown]
# # 4. CNN + RNN

# %%
def create_cnn_rnn():
    np.random.seed(seed)
    K.clear_session()
    model = Sequential()
    model.add(Embedding(max_features, 128, input_length=X_train.shape[1]))
    model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(LSTM(100, dropout=0.1, recurrent_dropout=0.1))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    return model

# %%
# create the model
model = create_cnn_rnn()
# callbacks
file_path = 'weights_best_cnn_rnn.hdf5'
early_stop = EarlyStopping(monitor='val_acc', patience=10, verbose=0, mode='max') #'val_acc'
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max') #'val_acc'
callbacks_list = [checkpoint, early_stop]
# train the model
model_history = model.fit(X_train, y_train, validation_data=(X_test, y_test), 
                          epochs=epochs, batch_size=batch_size,
                          callbacks=callbacks_list, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 128)           1280000
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 25, 32)            12320
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 12, 32)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               53200
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                2020
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 1,347,561
# Trainable params: 1,347,561
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3380 samples, validate on 845 samples
# Epoch 1/100
# Epoch 00001: val_acc improved from -inf to 0.80118, saving model to weights_best_cnn_rnn.hdf5
#  - 8s - loss: 0.5308 - acc: 0.7385 - val_loss: 0.4249 - val_acc: 0.8012
# Epoch 2/100
# Epoch 00002: val_acc improved from 0.80118 to 0.84379, saving model to weights_best_cnn_rnn.hdf5
#  - 6s - loss: 0.2909 - acc: 0.8873 - val_loss: 0.3641 - val_acc: 0.8438
# Epoch 3/100
# Epoch 00003: val_acc did not improve
#  - 6s - loss: 0.1450 - acc: 0.9462 - val_loss: 0.4345 - val_acc: 0.8189
# Epoch 4/100
# Epoch 00004: val_acc did not improve
#  - 6s - loss: 0.0930 - acc: 0.9636 - val_loss: 0.4724 - val_acc: 0.8225
# Epoch 5/100
# Epoch 00005: val_acc did not improve
#  - 6s - loss: 0.0721 - acc: 0.9713 - val_loss: 0.5412 - val_acc: 0.8272
# Epoch 6/100
# Epoch 00006: val_acc did not improve
#  - 6s - loss: 0.0544 - acc: 0.9757 - val_loss: 0.5249 - val_acc: 0.8237
# Epoch 7/100
# Epoch 00007: val_acc did not improve
#  - 6s - loss: 0.0499 - acc: 0.9754 - val_loss: 0.5976 - val_acc: 0.8201
# Epoch 8/100
# Epoch 00008: val_acc did not improve
#  - 6s - loss: 0.0433 - acc: 0.9781 - val_loss: 0.6521 - val_acc: 0.8249
# Epoch 9/100
# Epoch 00009: val_acc did not improve
#  - 6s - loss: 0.0417 - acc: 0.9799 - val_loss: 0.7526 - val_acc: 0.8249
# Epoch 10/100
# Epoch 00010: val_acc did not improve
#  - 6s - loss: 0.0374 - acc: 0.9781 - val_loss: 0.7593 - val_acc: 0.8272
# Epoch 11/100
# Epoch 00011: val_acc did not improve
#  - 6s - loss: 0.0339 - acc: 0.9811 - val_loss: 0.7248 - val_acc: 0.8331
# Epoch 12/100
# Epoch 00012: val_acc did not improve
#  - 5s - loss: 0.0352 - acc: 0.9805 - val_loss: 0.8430 - val_acc: 0.8284

# %%
plot_model_history(model_history)

# %%
model_evaluate('weights_best_cnn_rnn.hdf5')
# Out:
# Accuracy:	84.4%
# roc auc:	0.796
#
#
#              precision    recall  f1-score   support
#
#           0       0.71      0.70      0.70       223
#           1       0.89      0.90      0.89       622
#
# avg / total       0.84      0.84      0.84       845
